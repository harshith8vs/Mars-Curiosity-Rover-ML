# %% [markdown]
# # 05 — Model Comparison & Evaluation
# **Project:** Automated Classification of Martian Surface Images Captured by NASA's Curiosity Rover Using Machine Learning
#
# ### Objective:
# Comparative evaluation of all 5 trained models on the official test set. Computes accuracy, macro F1-score, precision, recall, confusion matrices, and per-class classification reports.
#
# ---
# > **Note:** Phase 1 Setup Notebook Skeleton. Pipeline execution is scheduled for subsequent phases.

# %%
# Basic environment check and path verification
import sys
from pathlib import Path

# Ensure project root is on sys.path
project_root = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

import config
print(f"Project root: {config.PROJECT_ROOT}")
print(f"Dataset directory: {config.DATA_DIR}")
print(f"Total expected classes: {config.NUM_EXPECTED_CLASSES}")
